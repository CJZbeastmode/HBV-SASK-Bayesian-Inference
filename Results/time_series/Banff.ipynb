# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('/Users/jay/Desktop/Bachelorarbeit/Implementation/dependencies/hbv_sask/data/Banff_Basin/streamflow.inp', delimiter='\t', header=None)
df.columns = ["date", "value"]
df["date"] = pd.to_datetime(df["date"])
df = df.set_index('date')
df
# Out:
#             value
# date
# 1950-01-01   7.82
# 1950-01-02   7.67
# 1950-01-03   7.82
# 1950-01-04   8.07
# 1950-01-05   8.21
# ...           ...
# 2011-12-27  11.10
# 2011-12-28  11.00
# 2011-12-29  11.10
# 2011-12-30  11.00
# 2011-12-31  11.10
#
# [22645 rows x 1 columns]

# %%
plt.plot(df['value'])

# %%
decompose_result_mult = seasonal_decompose(df, period=365)

#trend = decompose_result_mult.trend
#seasonal = decompose_result_mult.seasonal
#residual = decompose_result_mult.resid

decompose_result_mult.plot()
